# %%
import requests
from requests import ConnectionError,HTTPError,Timeout
url = 'https://data.ntpc.gov.tw/api/datasets/010E5B15-3823-4B20-B401-B1CF000550C5/json?page=0&size=2000'
try:
    response = requests.get(url)    
    response.raise_for_status()    
except ConnectionError:
    print('找不到伺服器')
except HTTPError:
    print('網頁找不到')
except Timeout:
    print('超過時間沒有回應')
else:
    print('沒有發生問題')
# Out:
# 沒有發生問題

# %%
import pandas as pd
df1 = pd.DataFrame(response.json(),
                   columns=['sna','tot','sbi','sarea','ar','bemp'])
df1
# Out:
#                        sna tot sbi sarea                      ar bemp
# 0          YouBike2.0_下庄市場  20   4   八里區               舊城路21號(前)   16
# 1        YouBike2.0_八里行政中心  20   6   八里區    十三行路(靠中山路二段路口西南側人行道)   14
# 2    YouBike2.0_八里中庄市場綜合大樓  28  13   八里區    中山路一段268巷2號(對面汽車停車場)   15
# 3          YouBike2.0_大崁國小  20   6   八里區                忠八街2號(前)   14
# 4         YouBike2.0_龍形停車場  40   2   八里區        龍米路一段318號(對面停車場)   38
# ..                     ...  ..  ..   ...                     ...  ...
# 995        YouBike2.0_青潭國小  27   3   新店區                北宜路二段80號   24
# 996     YouBike2.0_中正路284巷  29   6   新店區           中正路284巷4弄3號南側   22
# 997      YouBike2.0_央北社會住宅  58  33   新店區        央北二路十四張口(西南側人行道)   19
# 998  YouBike2.0_中興路2段100巷口  21  11   新店區  五峰路63巷/中興路二段100巷口(天橋旁)   10
# 999      YouBike2.0_台北慈濟醫院  40  14   新店區              建國路289號旁空地   20
#
# [1000 rows x 6 columns]

# %%
df2 = df1.rename(columns={'sna':'站名', 'sarea':'區域', 'ar':'地址', 'tot':'數量','sbi':'可借', 'bemp':'可還'})
df2
# Out:
#                         站名  數量  可借   區域                      地址  可還
# 0          YouBike2.0_下庄市場  20   4  八里區               舊城路21號(前)  16
# 1        YouBike2.0_八里行政中心  20   6  八里區    十三行路(靠中山路二段路口西南側人行道)  14
# 2    YouBike2.0_八里中庄市場綜合大樓  28  13  八里區    中山路一段268巷2號(對面汽車停車場)  15
# 3          YouBike2.0_大崁國小  20   6  八里區                忠八街2號(前)  14
# 4         YouBike2.0_龍形停車場  40   2  八里區        龍米路一段318號(對面停車場)  38
# ..                     ...  ..  ..  ...                     ...  ..
# 995        YouBike2.0_青潭國小  27   3  新店區                北宜路二段80號  24
# 996     YouBike2.0_中正路284巷  29   6  新店區           中正路284巷4弄3號南側  22
# 997      YouBike2.0_央北社會住宅  58  33  新店區        央北二路十四張口(西南側人行道)  19
# 998  YouBike2.0_中興路2段100巷口  21  11  新店區  五峰路63巷/中興路二段100巷口(天橋旁)  10
# 999      YouBike2.0_台北慈濟醫院  40  14  新店區              建國路289號旁空地  20
#
# [1000 rows x 6 columns]
