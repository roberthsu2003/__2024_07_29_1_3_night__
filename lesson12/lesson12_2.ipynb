# %%
import requests
from requests import Response
youbike_url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
try:
    respons:Response = requests.request('GET',youbike_url)
    respons.raise_for_status()
except Exception:
    print("下載錯誤")
else:
    content = respons.text

# %%
from pydantic import BaseModel, RootModel, Field
from pprint import pprint

#使用自訂的Fields的名稱
class Station(BaseModel):
    站名:str = Field(alias='sna')
    行政區:str = Field(alias='sarea')
    日期:str = Field(alias='mday')
    地址:str = Field(alias='ar')
    狀態:str = Field(alias='act')
    總車輛數:int = Field(alias='total')
    可借:int = Field(alias='available_rent_bikes')
    可還:int = Field(alias='available_return_bikes')

class Youbikes(RootModel):
    root:list[Station]

youbikes:Youbikes = Youbikes.model_validate_json(content)
youbikes_list = youbikes.model_dump()
pprint(youbikes_list)

# %%
for item in youbikes_list:
    pprint(item,indent=2)
# Out:
# { '可借': 1,
#   '可還': 27,
#   '地址': '復興南路二段235號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運科技大樓站',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 19,
#   '地址': '復興南路二段273號西側',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_復興南路二段273號前',
#   '總車輛數': 21,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 13,
#   '地址': '和平東路二段96巷7號',
#   '日期': '2024-09-04 19:42:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_國北教大實小東側門',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 5,
#   '地址': '和平東路二段118巷33號',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平公園東側',
#   '總車輛數': 11,
#   '行政區': '大安區'}
# { '可借': 11,
#   '可還': 5,
#   '地址': '復興南路二段368號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_辛亥復興路口西北側',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 25,
#   '地址': '復興南路二段280號',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_復興南路二段280號前',
#   '總車輛數': 27,
#   '行政區': '大安區'}
# { '可借': 4,
#   '可還': 7,
#   '地址': '復興南路二段342號',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_復興南路二段340巷口',
#   '總車輛數': 11,
#   '行政區': '大安區'}
# { '可借': 12,
#   '可還': 5,
#   '地址': '新生南路三段52號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_新生南路三段52號前',
#   '總車輛數': 17,
#   '行政區': '大安區'}
# { '可借': 7,
#   '可還': 9,
#   '地址': '新生南路三段66號東側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_新生南路三段66號前',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 13,
#   '可還': 7,
#   '地址': '新生南路三段82號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_新生南路三段82號前',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 0,
#   '地址': '辛亥路一段30號',
#   '日期': '2024-09-04 19:42:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_辛亥路一段30號前',
#   '總車輛數': 8,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 3,
#   '地址': '復興南路二段236號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平復興路口西北側',
#   '總車輛數': 9,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 6,
#   '地址': '羅斯福路三段311號',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_羅斯福路三段311號前',
#   '總車輛數': 11,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 14,
#   '地址': '敦南街76巷28號',
#   '日期': '2024-09-04 19:42:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大安運動中心停車場',
#   '總車輛數': 14,
#   '行政區': '大安區'}
# { '可借': 7,
#   '可還': 1,
#   '地址': '羅斯福路三段245號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_羅斯福路三段245號前',
#   '總車輛數': 8,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 0,
#   '地址': '羅斯福路三段283巷11號',
#   '日期': '2024-09-04 19:40:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_溫州公園',
#   '總車輛數': 5,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 24,
#   '地址': '臥龍街1號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平臥龍街口',
#   '總車輛數': 24,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 5,
#   '地址': '新生南路三段54巷/溫州街口',
#   '日期': '2024-08-13 07:53:15',
#   '狀態': '0',
#   '站名': 'YouBike2.0_溫州停車場',
#   '總車輛數': 5,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 1,
#   '地址': '羅斯福路四段21號旁天橋下',
#   '日期': '2024-09-04 19:42:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_銘傳國小側門',
#   '總車輛數': 7,
#   '行政區': '大安區'}
# { '可借': 14,
#   '可還': 16,
#   '地址': '捷運公館站(2號出口)外側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運公館站(2號出口)',
#   '總車輛數': 99,
#   '行政區': '大安區'}
# { '可借': 24,
#   '可還': 1,
#   '地址': '羅斯福路四段107號(西南側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_第二學生活動中心',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 48,
#   '地址': '基隆路四段43號(臺灣科技大學正門旁小側門靠田徑場)',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺灣科技大學正門',
#   '總車輛數': 50,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 97,
#   '地址': '基隆路四段73巷與基隆路口',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺灣科技大學側門',
#   '總車輛數': 99,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 14,
#   '地址': '羅斯福路四段113巷基隆路四段41巷口',
#   '日期': '2024-09-04 19:41:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_公館公園',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 36,
#   '地址': '基隆路四段41巷68弄臺科帆船大樓旁',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺灣科技大學後門',
#   '總車輛數': 39,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 18,
#   '地址': '基隆路三段155巷57號西側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大醫學院附設癌醫中心',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 14,
#   '地址': '芳蘭路/基隆路三段155巷口',
#   '日期': '2024-09-04 19:33:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大環研大樓',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 33,
#   '地址': '芳蘭路51號西北側',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大永齡生醫工程館',
#   '總車輛數': 34,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 19,
#   '地址': '長興街/長興街80巷口西側',
#   '日期': '2024-09-04 19:44:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大男七舍前',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 12,
#   '可還': 48,
#   '地址': '長興街50號西北側',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大男一舍前',
#   '總車輛數': 61,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 45,
#   '地址': '大安區長興街31號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大男六舍前',
#   '總車輛數': 46,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 18,
#   '地址': '基隆路三段155巷/基隆路四段口',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大動物醫院前',
#   '總車輛數': 18,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 24,
#   '地址': '辛亥路三段188號',
#   '日期': '2024-09-04 19:36:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大土木研究大樓前',
#   '總車輛數': 24,
#   '行政區': '大安區'}
# { '可借': 9,
#   '可還': 11,
#   '地址': '臺大萬才館北側',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大萬才館前',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 19,
#   '地址': '辛亥路三段30號西北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大國青大樓宿舍前',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 27,
#   '地址': '辛亥路與復興南路口西南側',
#   '日期': '2024-09-04 19:37:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大社科院圖書館前',
#   '總車輛數': 27,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 28,
#   '地址': '臺大法人語言訓練中心北側',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大法人語言訓練中心前',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 24,
#   '地址': '臺大綜合體育館北側',
#   '日期': '2024-09-04 19:32:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大綜合體育館停車場前',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 35,
#   '地址': '辛亥新生路口東南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_辛亥新生路口東南側',
#   '總車輛數': 41,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 15,
#   '地址': '基隆長興路口東側',
#   '日期': '2024-09-04 19:41:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_基隆長興路口東側',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 34,
#   '地址': '敦南街51號',
#   '日期': '2024-09-04 19:22:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_國北教大側門南側',
#   '總車輛數': 34,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 25,
#   '地址': '敦南街73號',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平實小東北側',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 4,
#   '可還': 19,
#   '地址': '辛亥路三段15號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大安區健康服務中心',
#   '總車輛數': 23,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 12,
#   '地址': '辛亥泰順街口東南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_辛亥泰順街口',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 31,
#   '地址': '臥龍街170號(前)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_芳和國中',
#   '總車輛數': 37,
#   '行政區': '大安區'}
# { '可借': 33,
#   '可還': 8,
#   '地址': '臥龍街234-2號',
#   '日期': '2024-09-04 19:41:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臥龍樂業街口',
#   '總車輛數': 41,
#   '行政區': '大安區'}
# { '可借': 11,
#   '可還': 14,
#   '地址': '辛亥路三段223號西側',
#   '日期': '2024-09-04 19:29:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臥龍公園',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 16,
#   '可還': 24,
#   '地址': '樂業街101巷3號西北側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_嘉興公園',
#   '總車輛數': 44,
#   '行政區': '大安區'}
# { '可借': 20,
#   '可還': 30,
#   '地址': '和平東路三段420號東北側',
#   '日期': '2024-09-04 19:37:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運麟光站(2號出口)',
#   '總車輛數': 50,
#   '行政區': '大安區'}
# { '可借': 15,
#   '可還': 49,
#   '地址': '和平東路三段410號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運六張犁站',
#   '總車輛數': 64,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 24,
#   '地址': '基隆路二段166號',
#   '日期': '2024-09-04 19:41:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_喬治工商',
#   '總車輛數': 24,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 5,
#   '地址': '通化街189號西側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_法治公園',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 7,
#   '可還': 11,
#   '地址': '辛亥路一段/羅斯福路三段口北側(辛亥路側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運臺電大樓站(2號出口)',
#   '總車輛數': 18,
#   '行政區': '大安區'}
# { '可借': 18,
#   '可還': 27,
#   '地址': '和平東路一段/金山南路二段西南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平金山路口',
#   '總車輛數': 45,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 26,
#   '地址': '和平東路一段/龍泉街口西南側',
#   '日期': '2024-09-04 19:43:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平龍泉街口',
#   '總車輛數': 34,
#   '行政區': '大安區'}
# { '可借': 9,
#   '可還': 0,
#   '地址': '和平東路一段/泰順街口東南側',
#   '日期': '2024-09-04 19:44:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平泰順街口',
#   '總車輛數': 9,
#   '行政區': '大安區'}
# { '可借': 30,
#   '可還': 10,
#   '地址': '和平東路一段129號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺灣師範大學(圖書館)',
#   '總車輛數': 40,
#   '行政區': '大安區'}
# { '可借': 7,
#   '可還': 53,
#   '地址': '羅斯福路二段41號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運古亭站(6號出口)',
#   '總車輛數': 60,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 8,
#   '地址': '和平東路一段19號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運古亭站(5號出口)',
#   '總車輛數': 14,
#   '行政區': '大安區'}
# { '可借': 41,
#   '可還': 10,
#   '地址': '建國南路二段/建國南路二段151巷(橋下空間)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北市立圖書館(總館)',
#   '總車輛數': 51,
#   '行政區': '大安區'}
# { '可借': 12,
#   '可還': 39,
#   '地址': '新生南路二段與和平東路二段口東北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_新生和平路口東北側',
#   '總車輛數': 51,
#   '行政區': '大安區'}
# { '可借': 17,
#   '可還': 33,
#   '地址': '建國南路二段與和平東路二段口西北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_建國和平路口西北側',
#   '總車輛數': 50,
#   '行政區': '大安區'}
# { '可借': 42,
#   '可還': 2,
#   '地址': '金華街249號對面',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_金華公園',
#   '總車輛數': 44,
#   '行政區': '大安區'}
# { '可借': 10,
#   '可還': 5,
#   '地址': '信義路二段128號前',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運東門站(3號出口)',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 9,
#   '可還': 3,
#   '地址': '信義路二段與杭州南路二段東南側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_金甌女中',
#   '總車輛數': 12,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 17,
#   '地址': '愛國東路21巷與杭州南路二段25巷口東南側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_金杭公園',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 43,
#   '地址': '愛國東路與杭州南路二段口西南側',
#   '日期': '2024-08-23 00:27:14',
#   '狀態': '0',
#   '站名': 'YouBike2.0_愛國金山路口',
#   '總車輛數': 43,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 14,
#   '地址': '敦化南路二段293巷口南側',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦化南路二段293巷口南側',
#   '總車輛數': 14,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 37,
#   '地址': '敦化南路二段218號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦化基隆路口',
#   '總車輛數': 38,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 29,
#   '地址': '安和路二段185號',
#   '日期': '2024-09-04 19:32:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_安和路二段181巷口',
#   '總車輛數': 29,
#   '行政區': '大安區'}
# { '可借': 12,
#   '可還': 13,
#   '地址': '通化街111號',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臨江街夜市(通化街101巷口)',
#   '總車輛數': 30,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 21,
#   '地址': '基隆路二段108號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臨江街夜市(基隆路)',
#   '總車輛數': 29,
#   '行政區': '大安區'}
# { '可借': 4,
#   '可還': 41,
#   '地址': '忠孝東路三段81號',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_台北科技大學億光大樓',
#   '總車輛數': 45,
#   '行政區': '大安區'}
# { '可借': 9,
#   '可還': 24,
#   '地址': '新生南路一段113號',
#   '日期': '2024-09-04 19:43:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_新生南路一段119巷口',
#   '總車輛數': 33,
#   '行政區': '大安區'}
# { '可借': 10,
#   '可還': 18,
#   '地址': '仁愛路三段22號',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_幸安國小(仁愛路)',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 15,
#   '可還': 0,
#   '地址': '建國南路一段304巷45號南側',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_民榮公園',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 49,
#   '地址': '復興南路一段信義路三段147巷45弄口',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_復興南路1段340巷口',
#   '總車輛數': 50,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 51,
#   '地址': '建國南路一段/濟南路三段口(東南側)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_建國濟南路口',
#   '總車輛數': 54,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 40,
#   '地址': '復興南路一段/仁愛路三段123巷13弄(西北側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝復興站(2號出口)',
#   '總車輛數': 43,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 11,
#   '地址': '信義路4段6號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大安站(4號出口)',
#   '總車輛數': 13,
#   '行政區': '大安區'}
# { '可借': 4,
#   '可還': 18,
#   '地址': '信義路3段143號(前)',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大安站(2號出口)',
#   '總車輛數': 22,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 15,
#   '地址': '信義路四段74號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_信義大安路口(信維大樓)',
#   '總車輛數': 18,
#   '行政區': '大安區'}
# { '可借': 15,
#   '可還': 55,
#   '地址': '敦化南路一段與敦化南路一段236巷口',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_龍門廣場',
#   '總車輛數': 70,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 29,
#   '地址': '仁愛路四段258號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛安和路口',
#   '總車輛數': 33,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 47,
#   '地址': '信義路四段155號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_信義敦化路口',
#   '總車輛數': 52,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 25,
#   '地址': '安和路一段75號(對面)',
#   '日期': '2024-09-04 19:44:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛國中',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 18,
#   '可還': 6,
#   '地址': '信義路四段188號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運信義安和站(2號出口)',
#   '總車輛數': 24,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 29,
#   '地址': '市民大道三段170號',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_八德市場',
#   '總車輛數': 30,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 13,
#   '地址': '市民大道三段206號西側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_昌隆公園',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 38,
#   '可還': 31,
#   '地址': '捷運大安森林公園站(2號出口)西側',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大安森林公園站(2號出口)',
#   '總車輛數': 69,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 14,
#   '地址': '信義路四段353號',
#   '日期': '2024-09-04 19:25:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_信義延吉街口',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 20,
#   '可還': 5,
#   '地址': '延吉街249號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_光信公園(光復南路456巷)',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 13,
#   '地址': '光復南路290巷5號',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_僑安地下停車場(2號出口)東南側',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 21,
#   '可還': 11,
#   '地址': '建國南路一段275號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_建國南路一段279巷口',
#   '總車輛數': 32,
#   '行政區': '大安區'}
# { '可借': 13,
#   '可還': 2,
#   '地址': '新生南路一段101號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝新生站(6號出口)',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 26,
#   '地址': '忠孝新生路口北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝新生站(4號出口)',
#   '總車輛數': 34,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 20,
#   '地址': '復興南路二段52號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大安高工',
#   '總車輛數': 23,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 20,
#   '地址': '忠孝東路三段與10巷口',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝新生站(3號出口)',
#   '總車輛數': 23,
#   '行政區': '大安區'}
# { '可借': 20,
#   '可還': 0,
#   '地址': '忠孝東路四段49巷4弄/大安路口',
#   '日期': '2024-09-04 19:44:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_瑠公公園',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 7,
#   '可還': 14,
#   '地址': '敦化南路1段158號(前)',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦化市民路口',
#   '總車輛數': 23,
#   '行政區': '大安區'}
# { '可借': 13,
#   '可還': 2,
#   '地址': '捷運大安森林公園站(5號出口)東側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大安森林公園站(5號出口)',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 16,
#   '可還': 36,
#   '地址': '建國南路二段與信義路三段口西南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_信義建國路口',
#   '總車輛數': 52,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 17,
#   '地址': '東豐街24號(旁公園路側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_東豐公園',
#   '總車輛數': 19,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 12,
#   '地址': '四維路66巷6號北側',
#   '日期': '2024-09-04 19:39:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_德安公園(四維路66巷)',
#   '總車輛數': 14,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 41,
#   '地址': '復興南路一段135巷3號(對面)',
#   '日期': '2024-07-26 03:30:25',
#   '狀態': '0',
#   '站名': 'YouBike2.0_捷運忠孝復興站(5號出口)',
#   '總車輛數': 41,
#   '行政區': '大安區'}
# { '可借': 11,
#   '可還': 5,
#   '地址': '忠孝東路四段221號',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝敦化站(2號出口)',
#   '總車輛數': 17,
#   '行政區': '大安區'}
# { '可借': 15,
#   '可還': 3,
#   '地址': '忠孝東路四段143號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝敦化站(7號出口)',
#   '總車輛數': 18,
#   '行政區': '大安區'}
# { '可借': 19,
#   '可還': 5,
#   '地址': '忠孝東路四段223巷77號北側',
#   '日期': '2024-09-04 19:36:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠孝東路四段223巷口(市民大道側)',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 14,
#   '地址': '瑞安街208巷39號對面',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_瑞安街208巷',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 11,
#   '地址': '樂利路25號',
#   '日期': '2024-09-04 19:37:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_樂利路21巷口',
#   '總車輛數': 17,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 52,
#   '地址': '和平東路二段134號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運科技大樓站(台北教育大學)',
#   '總車輛數': 54,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 43,
#   '地址': '忠孝東路四段/光復南路口(西南側)',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運國父紀念館站(2號出口)',
#   '總車輛數': 45,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 30,
#   '地址': '仁愛路四段/大安路一段口(西南側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛醫院',
#   '總車輛數': 36,
#   '行政區': '大安區'}
# { '可借': 20,
#   '可還': 28,
#   '地址': '信義路四段252號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運信義安和站(4號出口)',
#   '總車輛數': 49,
#   '行政區': '大安區'}
# { '可借': 16,
#   '可還': 20,
#   '地址': '和平東路三段1巷/四維路198巷口(西北側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_成功國宅',
#   '總車輛數': 36,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 31,
#   '地址': '仁愛路四段376號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛延吉街口',
#   '總車輛數': 33,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 33,
#   '地址': '信義路四段225號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運信義安和站(1號出口)',
#   '總車輛數': 33,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 24,
#   '地址': '敦化南路二段99號前',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦化南路二段103巷口',
#   '總車輛數': 24,
#   '行政區': '大安區'}
# { '可借': 37,
#   '可還': 0,
#   '地址': '復興南路二段142之1號前',
#   '日期': '2024-09-04 19:42:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_復興南路二段128巷口',
#   '總車輛數': 37,
#   '行政區': '大安區'}
# { '可借': 11,
#   '可還': 6,
#   '地址': '和平東路/建國南路口(北側)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平東建國南路口',
#   '總車輛數': 17,
#   '行政區': '大安區'}
# { '可借': 9,
#   '可還': 7,
#   '地址': '基隆路三段155巷148號',
#   '日期': '2024-09-04 19:36:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_芳蘭山莊',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 12,
#   '可還': 3,
#   '地址': '復興南路一段126巷1號前',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_復興南路一段126巷口',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 14,
#   '可還': 14,
#   '地址': '信義路二段178號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運東門站(5號出口)',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 9,
#   '地址': '仁愛路四段48巷/東豐街(北側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛路四段48巷口',
#   '總車輛數': 12,
#   '行政區': '大安區'}
# { '可借': 81,
#   '可還': 17,
#   '地址': '捷運公館站(3號出口)西側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運公館站(3號出口)',
#   '總車輛數': 99,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 15,
#   '地址': '忠孝東路三段100號對側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北科技大學(電機工程系)',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 11,
#   '可還': 4,
#   '地址': '新生南路三段94號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_新生南路三段94巷口',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 9,
#   '地址': '辛亥路一段/新生南路三段(西北側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_辛亥新生路口西北側',
#   '總車輛數': 12,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 14,
#   '地址': '復興南路一段303號前',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大安站(6號出口)',
#   '總車輛數': 19,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 6,
#   '地址': '臥龍街/臥龍街195巷(南側)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臥龍街195巷口',
#   '總車輛數': 14,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 26,
#   '地址': '辛亥路三段與辛亥路三段157巷口西北側',
#   '日期': '2024-09-04 19:33:21',
#   '狀態': '1',
#   '站名': 'YouBike2.0_辛亥路三段157巷口',
#   '總車輛數': 27,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 28,
#   '地址': '臥龍街與基隆路二段口東北側',
#   '日期': '2024-09-04 19:36:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臥龍基隆路口',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 14,
#   '可還': 12,
#   '地址': '和平東路二段96巷8之1號(前方)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦親公園',
#   '總車輛數': 26,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 30,
#   '地址': '辛亥路三段55號前方人行道(大安運動中心)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大安運動中心',
#   '總車輛數': 33,
#   '行政區': '大安區'}
# { '可借': 4,
#   '可還': 32,
#   '地址': '和平東路三段 / 敦化南路二段口(東側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平敦化路口',
#   '總車輛數': 36,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 47,
#   '地址': '基隆路/長興街(東南側)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_基隆長興路口',
#   '總車輛數': 51,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 24,
#   '地址': '仁愛路四段118號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛路四段122巷口',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 22,
#   '地址': '敦化南路一段111號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_市民敦化路口',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 13,
#   '可還': 2,
#   '地址': '忠孝東路四段55號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠孝東路四段49巷口',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 13,
#   '可還': 3,
#   '地址': '市民大道四段/復興路一段口(東南側)',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_市民復興路口(東南側)',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 13,
#   '可還': 0,
#   '地址': '新生南路三段2號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平新生路口西南側',
#   '總車輛數': 13,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 13,
#   '地址': '安和路二段227巷16號對側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_全安公園',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 17,
#   '地址': '信義路三段/信義路三段134巷口',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_信義路三段134巷口',
#   '總車輛數': 19,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 15,
#   '地址': '仁愛路四段110號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛敦南圓環(東南側)',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 33,
#   '地址': '敦化南路二段201號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北遠企購物中心',
#   '總車輛數': 33,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 23,
#   '地址': '敦化南路一段280號',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_外交部外交及國際事務學院',
#   '總車輛數': 26,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 22,
#   '地址': '敦化南路二段92號對側中央分隔島',
#   '日期': '2024-09-04 19:37:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_四維路170巷口',
#   '總車輛數': 22,
#   '行政區': '大安區'}
# { '可借': 21,
#   '可還': 25,
#   '地址': '信義路三段184號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大安站(3號出口)',
#   '總車輛數': 46,
#   '行政區': '大安區'}
# { '可借': 27,
#   '可還': 11,
#   '地址': '羅斯福路三段201號旁',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運臺電大樓站(2號出口)_1',
#   '總車輛數': 38,
#   '行政區': '大安區'}
# { '可借': 12,
#   '可還': 3,
#   '地址': '信義路四段199巷/安和路一段90巷口',
#   '日期': '2024-09-04 19:43:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_信義路四段199巷',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 40,
#   '地址': '辛亥路二段(臺大外語學院外)',
#   '日期': '2024-09-04 19:25:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大資訊大樓',
#   '總車輛數': 40,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 39,
#   '地址': '敦化南路二段與敦化南路二段81巷口西北側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦化南路二段81巷',
#   '總車輛數': 40,
#   '行政區': '大安區'}
# { '可借': 20,
#   '可還': 3,
#   '地址': '金華街78號對側',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_原臺北刑務所官舍',
#   '總車輛數': 23,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 22,
#   '地址': '光復南路200巷26號東側',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運國父紀念館站(1號出口)',
#   '總車輛數': 24,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 14,
#   '地址': '忠孝東路三段248巷30號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_懷生國中',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 15,
#   '地址': '仁愛路四段85號前',
#   '日期': '2024-09-04 19:43:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛敦南圓環(西北側)',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 15,
#   '地址': '安和路二段/敦化南路二段81巷(西南側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_立人國小',
#   '總車輛數': 17,
#   '行政區': '大安區'}
# { '可借': 14,
#   '可還': 10,
#   '地址': '辛亥路二段43號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平東路二段18巷口',
#   '總車輛數': 24,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 22,
#   '地址': '復興南路二段/信義路四段(東南側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大安站(5號出口)',
#   '總車輛數': 26,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 15,
#   '地址': '通化街143巷33號對側',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臨江公園',
#   '總車輛數': 23,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 13,
#   '地址': '羅斯福路四段119巷84號對側',
#   '日期': '2024-09-04 19:33:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_羅斯福路四段113巷19弄口',
#   '總車輛數': 14,
#   '行政區': '大安區'}
# { '可借': 20,
#   '可還': 5,
#   '地址': '忠孝東路四段230號前',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠孝東路四段248巷口',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 18,
#   '地址': '仁愛路四段363號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛延吉路口(西北側)',
#   '總車輛數': 18,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 1,
#   '地址': '樂利路97號前',
#   '日期': '2024-09-04 19:40:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_樂利路101巷口',
#   '總車輛數': 13,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 8,
#   '地址': '羅斯福路三段117號前',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_羅斯福浦城街口',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 8,
#   '可還': 10,
#   '地址': '敦化南路一段295巷1號',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦化南路一段295巷口',
#   '總車輛數': 18,
#   '行政區': '大安區'}
# { '可借': 14,
#   '可還': 6,
#   '地址': '通安街129號對面',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_通安區民活動中心',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 20,
#   '可還': 8,
#   '地址': '復興南路一段191號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_復興忠孝東路口(東南側)',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 18,
#   '地址': '仁愛路四段37號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛大安路口(東北側)',
#   '總車輛數': 21,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 8,
#   '地址': '浦城街1號對側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺灣師範大學(浦城街)',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 19,
#   '可還': 1,
#   '地址': '安和路二段/安和路二段69巷',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_安和路二段69巷口',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 5,
#   '可還': 20,
#   '地址': '臥龍街131巷11弄與樂業街108巷口',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大安國小',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 13,
#   '地址': '羅斯福路二段81-1號前',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運古亭站(3號出口)',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 36,
#   '可還': 1,
#   '地址': '忠孝東路四段48號前',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝復興站(3號出口)',
#   '總車輛數': 37,
#   '行政區': '大安區'}
# { '可借': 4,
#   '可還': 16,
#   '地址': '和平東路二段90巷/和平東路二段76巷5弄',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平東路二段90巷',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 11,
#   '可還': 5,
#   '地址': '光復南路438號',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_光復南路420巷口',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 12,
#   '地址': '富陽街129號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_富陽臥龍街口',
#   '總車輛數': 18,
#   '行政區': '大安區'}
# { '可借': 3,
#   '可還': 22,
#   '地址': '仁愛路四段1號前',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛復興路口',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 2,
#   '可還': 14,
#   '地址': '仁愛路四段121號',
#   '日期': '2024-09-04 19:39:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_仁愛敦南圓環(東側)',
#   '總車輛數': 16,
#   '行政區': '大安區'}
# { '可借': 6,
#   '可還': 9,
#   '地址': '龍泉街93巷7號對側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_古風公園',
#   '總車輛數': 15,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 19,
#   '地址': '敦化南路二段9號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_敦化信義路口(東南側)',
#   '總車輛數': 20,
#   '行政區': '大安區'}
# { '可借': 0,
#   '可還': 21,
#   '地址': '忠孝東路三段132號前',
#   '日期': '2024-09-04 19:44:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠孝建國路口(東南側)',
#   '總車輛數': 21,
#   '行政區': '大安區'}
# { '可借': 10,
#   '可還': 7,
#   '地址': '浦城街26巷8號對面',
#   '日期': '2024-09-04 19:37:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_浦城街26巷',
#   '總車輛數': 17,
#   '行政區': '大安區'}
# { '可借': 14,
#   '可還': 11,
#   '地址': '辛亥路三段(青峰活動中心)',
#   '日期': '2024-09-04 19:29:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_青峰活動中心',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 1,
#   '可還': 27,
#   '地址': '忠孝東路三段218號前',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠孝東路三段216巷口',
#   '總車輛數': 28,
#   '行政區': '大安區'}
# { '可借': 15,
#   '可還': 9,
#   '地址': '忠孝東路四段7號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運忠孝復興站(4號出口)',
#   '總車輛數': 25,
#   '行政區': '大安區'}
# { '可借': 21,
#   '可還': 9,
#   '地址': '延平北路五段1-1號(對面)',
#   '日期': '2024-09-04 19:34:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_延平國宅',
#   '總車輛數': 30,
#   '行政區': '大同區'}
# { '可借': 5,
#   '可還': 15,
#   '地址': '重慶北路三段318號旁',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北市立圖書館大同分館',
#   '總車輛數': 20,
#   '行政區': '大同區'}
# { '可借': 6,
#   '可還': 8,
#   '地址': '環河北路二段371號旁',
#   '日期': '2024-09-04 19:39:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_合昌宮',
#   '總車輛數': 15,
#   '行政區': '大同區'}
# { '可借': 21,
#   '可還': 2,
#   '地址': '延平北路三段123號北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_民族延平路口',
#   '總車輛數': 36,
#   '行政區': '大同區'}
# { '可借': 27,
#   '可還': 17,
#   '地址': '重慶北路三段260號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶酒泉街口',
#   '總車輛數': 44,
#   '行政區': '大同區'}
# { '可借': 6,
#   '可還': 8,
#   '地址': '大龍街85巷12號對側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_樹德公園',
#   '總車輛數': 14,
#   '行政區': '大同區'}
# { '可借': 10,
#   '可還': 6,
#   '地址': '西寧北路112號前方',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_陳天來故居',
#   '總車輛數': 16,
#   '行政區': '大同區'}
# { '可借': 32,
#   '可還': 5,
#   '地址': '哈密街61號口對側人行道',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北孔廟',
#   '總車輛數': 37,
#   '行政區': '大同區'}
# { '可借': 2,
#   '可還': 42,
#   '地址': '捷運圓山站(1號出口)東側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運圓山站(1號出口)',
#   '總車輛數': 44,
#   '行政區': '大同區'}
# { '可借': 6,
#   '可還': 35,
#   '地址': '酒泉街235號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_酒泉延平路口',
#   '總車輛數': 41,
#   '行政區': '大同區'}
# { '可借': 2,
#   '可還': 47,
#   '地址': '敦煌路19號前',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶國中',
#   '總車輛數': 49,
#   '行政區': '大同區'}
# { '可借': 25,
#   '可還': 0,
#   '地址': '敦煌路與重慶北路三段383巷口',
#   '日期': '2024-09-04 19:33:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶北路三段383巷口',
#   '總車輛數': 25,
#   '行政區': '大同區'}
# { '可借': 24,
#   '可還': 0,
#   '地址': '承德路三段287號前方',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_台北數位產業園區',
#   '總車輛數': 24,
#   '行政區': '大同區'}
# { '可借': 1,
#   '可還': 19,
#   '地址': '民權西路239號前方',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_民權延平路口(西北側)',
#   '總車輛數': 20,
#   '行政區': '大同區'}
# { '可借': 26,
#   '可還': 21,
#   '地址': '民權西路與迪化街一段口(橋墩下)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_民權迪化街口',
#   '總車輛數': 47,
#   '行政區': '大同區'}
# { '可借': 12,
#   '可還': 23,
#   '地址': '安西街1巷7號(對側)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大稻埕公園',
#   '總車輛數': 35,
#   '行政區': '大同區'}
# { '可借': 14,
#   '可還': 0,
#   '地址': '民族西路82號前方',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大龍老人住宅',
#   '總車輛數': 14,
#   '行政區': '大同區'}
# { '可借': 16,
#   '可還': 4,
#   '地址': '承德路三段210號旁',
#   '日期': '2024-09-04 19:39:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大龍峒社會住宅',
#   '總車輛數': 20,
#   '行政區': '大同區'}
# { '可借': 11,
#   '可還': 46,
#   '地址': '捷運大橋頭站(2號出口)西側',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大橋頭站(2號出口)',
#   '總車輛數': 57,
#   '行政區': '大同區'}
# { '可借': 9,
#   '可還': 9,
#   '地址': '民權西路237號旁',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運大橋頭站(1A出口)',
#   '總車輛數': 18,
#   '行政區': '大同區'}
# { '可借': 0,
#   '可還': 25,
#   '地址': '捷運民權西路站(2號出口)西側',
#   '日期': '2024-09-04 19:37:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運民權西路站(2號出口)',
#   '總車輛數': 25,
#   '行政區': '大同區'}
# { '可借': 1,
#   '可還': 40,
#   '地址': '萬全街22號對面',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運雙連站(2號出口)',
#   '總車輛數': 41,
#   '行政區': '大同區'}
# { '可借': 3,
#   '可還': 59,
#   '地址': '塔城街與鄭州路口西南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運北門站(3號出口)',
#   '總車輛數': 62,
#   '行政區': '大同區'}
# { '可借': 3,
#   '可還': 7,
#   '地址': '重慶北路二段62-1號旁',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_朝陽公園',
#   '總車輛數': 10,
#   '行政區': '大同區'}
# { '可借': 7,
#   '可還': 31,
#   '地址': '南京西路233巷103號旁',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_永樂市場',
#   '總車輛數': 38,
#   '行政區': '大同區'}
# { '可借': 15,
#   '可還': 3,
#   '地址': '大龍街217號對側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大龍公園',
#   '總車輛數': 18,
#   '行政區': '大同區'}
# { '可借': 0,
#   '可還': 13,
#   '地址': '重慶北路二段180號旁',
#   '日期': '2024-09-04 19:27:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶涼州街口',
#   '總車輛數': 13,
#   '行政區': '大同區'}
# { '可借': 5,
#   '可還': 9,
#   '地址': '玉門街/民族西路(西北側)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_圓山線形公園',
#   '總車輛數': 14,
#   '行政區': '大同區'}
# { '可借': 16,
#   '可還': 13,
#   '地址': '重慶北路一段128號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_圓環站',
#   '總車輛數': 31,
#   '行政區': '大同區'}
# { '可借': 18,
#   '可還': 8,
#   '地址': '重慶北路三段162號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶民族路口',
#   '總車輛數': 26,
#   '行政區': '大同區'}
# { '可借': 1,
#   '可還': 20,
#   '地址': '承德路三段14號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_承德路三段8巷口',
#   '總車輛數': 21,
#   '行政區': '大同區'}
# { '可借': 9,
#   '可還': 22,
#   '地址': '鄭州路23號(旁)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_太原廣場',
#   '總車輛數': 31,
#   '行政區': '大同區'}
# { '可借': 17,
#   '可還': 1,
#   '地址': '昌吉街117號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_國順公園',
#   '總車輛數': 20,
#   '行政區': '大同區'}
# { '可借': 16,
#   '可還': 24,
#   '地址': '長安西路299號(對面)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_聯合醫院中興院區',
#   '總車輛數': 40,
#   '行政區': '大同區'}
# { '可借': 14,
#   '可還': 22,
#   '地址': '錦西街/興城街口(西南側)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_蔣渭水紀念公園',
#   '總車輛數': 36,
#   '行政區': '大同區'}
# { '可借': 9,
#   '可還': 6,
#   '地址': '延平北路四段200號(南側)',
#   '日期': '2024-09-04 19:34:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_迪化休閒運動公園',
#   '總車輛數': 15,
#   '行政區': '大同區'}
# { '可借': 12,
#   '可還': 3,
#   '地址': '大龍街51號(旁)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大同運動中心',
#   '總車輛數': 16,
#   '行政區': '大同區'}
# { '可借': 15,
#   '可還': 5,
#   '地址': '重慶北路二段171號(旁)',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶保安街口(家樂福重慶店)',
#   '總車輛數': 20,
#   '行政區': '大同區'}
# { '可借': 22,
#   '可還': 30,
#   '地址': '大稻埕疏散門(淡五號水門)外',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大稻埕碼頭',
#   '總車輛數': 52,
#   '行政區': '大同區'}
# { '可借': 16,
#   '可還': 4,
#   '地址': '重慶北路二段/歸綏街口(南側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_歸綏戲曲公園',
#   '總車輛數': 20,
#   '行政區': '大同區'}
# { '可借': 2,
#   '可還': 15,
#   '地址': '民權西路/蘭州街(西側)',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_民權國中(民權西路)',
#   '總車輛數': 17,
#   '行政區': '大同區'}
# { '可借': 0,
#   '可還': 17,
#   '地址': '承德路二段239號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_承德民權路口',
#   '總車輛數': 17,
#   '行政區': '大同區'}
# { '可借': 9,
#   '可還': 18,
#   '地址': '南京西路/太原路(東側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_南京太原路口',
#   '總車輛數': 29,
#   '行政區': '大同區'}
# { '可借': 1,
#   '可還': 9,
#   '地址': '承德路二段137號前',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_承德民生西路口',
#   '總車輛數': 10,
#   '行政區': '大同區'}
# { '可借': 17,
#   '可還': 15,
#   '地址': '太原路 / 五原路口(東南側)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_太原五原路口',
#   '總車輛數': 32,
#   '行政區': '大同區'}
# { '可借': 5,
#   '可還': 15,
#   '地址': '華陰街45號(對面)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北轉運站(華陰街)',
#   '總車輛數': 20,
#   '行政區': '大同區'}
# { '可借': 0,
#   '可還': 50,
#   '地址': '民權西路70巷37號對面',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運民權西路站(3號出口)',
#   '總車輛數': 50,
#   '行政區': '大同區'}
# { '可借': 1,
#   '可還': 17,
#   '地址': '南京西路57號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運中山站(5號出口)',
#   '總車輛數': 18,
#   '行政區': '大同區'}
# { '可借': 15,
#   '可還': 0,
#   '地址': '長安西路244號(重慶路側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶長安路口',
#   '總車輛數': 15,
#   '行政區': '大同區'}
# { '可借': 9,
#   '可還': 9,
#   '地址': '承德路三段83號前',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_承德昌吉街口',
#   '總車輛數': 18,
#   '行政區': '大同區'}
# { '可借': 13,
#   '可還': 1,
#   '地址': '環河北路一段/民生西路口(東南側)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大同16號廣場',
#   '總車輛數': 14,
#   '行政區': '大同區'}
# { '可借': 2,
#   '可還': 35,
#   '地址': '承德路三段/庫倫街(東南側)',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運圓山站(2號出口)',
#   '總車輛數': 37,
#   '行政區': '大同區'}
# { '可借': 29,
#   '可還': 11,
#   '地址': '大龍街/大龍街85巷(東北側)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_樹德公園_1',
#   '總車輛數': 40,
#   '行政區': '大同區'}
# { '可借': 18,
#   '可還': 20,
#   '地址': '承德路一段/鄭州路口(市民高架下)',
#   '日期': '2024-09-04 19:39:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_承德鄭州路口(市民高架下)',
#   '總車輛數': 38,
#   '行政區': '大同區'}
# { '可借': 4,
#   '可還': 10,
#   '地址': '錦西街與錦西街52巷口東北側',
#   '日期': '2024-09-04 19:37:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_成淵高中',
#   '總車輛數': 14,
#   '行政區': '大同區'}
# { '可借': 8,
#   '可還': 13,
#   '地址': '民權西路102巷4弄25號對側人行道',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_雙蓮國小',
#   '總車輛數': 21,
#   '行政區': '大同區'}
# { '可借': 1,
#   '可還': 14,
#   '地址': '寧夏路141號對側',
#   '日期': '2024-09-04 19:28:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_寧夏涼州街口',
#   '總車輛數': 15,
#   '行政區': '大同區'}
# { '可借': 5,
#   '可還': 9,
#   '地址': '延平北路二段/涼州街口(行人天橋下)',
#   '日期': '2024-09-04 19:40:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_延平涼州街口',
#   '總車輛數': 14,
#   '行政區': '大同區'}
# { '可借': 16,
#   '可還': 0,
#   '地址': '昌吉街63號旁',
#   '日期': '2024-09-04 19:37:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大同行政中心',
#   '總車輛數': 16,
#   '行政區': '大同區'}
# { '可借': 4,
#   '可還': 11,
#   '地址': '重慶北路三段335巷13號對面',
#   '日期': '2024-09-04 19:33:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大龍市場',
#   '總車輛數': 15,
#   '行政區': '大同區'}
# { '可借': 7,
#   '可還': 16,
#   '地址': '敦煌路78號',
#   '日期': '2024-09-04 19:39:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_哈密街23巷19弄口',
#   '總車輛數': 23,
#   '行政區': '大同區'}
# { '可借': 0,
#   '可還': 15,
#   '地址': '民權西路160巷口西側',
#   '日期': '2024-09-04 19:40:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_民權西路160巷口',
#   '總車輛數': 15,
#   '行政區': '大同區'}
# { '可借': 3,
#   '可還': 7,
#   '地址': '通河東街325巷/通河東街口',
#   '日期': '2024-09-04 19:37:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_劍潭抽水站',
#   '總車輛數': 17,
#   '行政區': '士林區'}
# { '可借': 5,
#   '可還': 7,
#   '地址': '通河東街1段192號(旁)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_通河東街大南路口',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 22,
#   '可還': 0,
#   '地址': '華齡街175號(旁)',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_福港街停車場',
#   '總車輛數': 22,
#   '行政區': '士林區'}
# { '可借': 13,
#   '可還': 35,
#   '地址': '前港街104號(對面)',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_百齡國小',
#   '總車輛數': 50,
#   '行政區': '士林區'}
# { '可借': 3,
#   '可還': 19,
#   '地址': '雨聲街/雨聲街165巷(西北側)',
#   '日期': '2024-09-04 18:49:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_雨聲街165巷口',
#   '總車輛數': 25,
#   '行政區': '士林區'}
# { '可借': 3,
#   '可還': 13,
#   '地址': '中山北路七段14巷(公園西側)',
#   '日期': '2024-09-04 19:29:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_天和公園',
#   '總車輛數': 16,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 25,
#   '地址': '天母西路3-55號前人行道',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_中山天母路口',
#   '總車輛數': 29,
#   '行政區': '士林區'}
# { '可借': 3,
#   '可還': 47,
#   '地址': '忠誠路二段/忠誠路二段207巷(東南側)',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_天母運動公園',
#   '總車輛數': 50,
#   '行政區': '士林區'}
# { '可借': 34,
#   '可還': 14,
#   '地址': '士東路276號至280號對面人行道',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北市立大學(天母校區)',
#   '總車輛數': 48,
#   '行政區': '士林區'}
# { '可借': 3,
#   '可還': 11,
#   '地址': '忠誠路2段53巷7號(對面)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠誠路二段53巷',
#   '總車輛數': 18,
#   '行政區': '士林區'}
# { '可借': 16,
#   '可還': 10,
#   '地址': '忠誠路二段122號(對面)',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_天母棒球場',
#   '總車輛數': 26,
#   '行政區': '士林區'}
# { '可借': 0,
#   '可還': 14,
#   '地址': '天母北路33號(前)',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_天母北天玉街口',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 29,
#   '可還': 26,
#   '地址': '中山北路六段/士東路(西北側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_蘭興公園',
#   '總車輛數': 56,
#   '行政區': '士林區'}
# { '可借': 8,
#   '可還': 0,
#   '地址': '承德路4段6巷71號(對面)',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_明勝公園',
#   '總車輛數': 14,
#   '行政區': '士林區'}
# { '可借': 2,
#   '可還': 21,
#   '地址': '中山北路4段/通河街口',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_劍潭海外青年活動中心',
#   '總車輛數': 23,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 5,
#   '地址': '忠誠路一段177號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠誠路一段173巷口',
#   '總車輛數': 11,
#   '行政區': '士林區'}
# { '可借': 16,
#   '可還': 0,
#   '地址': '忠義街6號對側',
#   '日期': '2024-09-04 19:38:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_雨農國小',
#   '總車輛數': 21,
#   '行政區': '士林區'}
# { '可借': 8,
#   '可還': 17,
#   '地址': '忠誠路一段18號(對面)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠誠公園',
#   '總車輛數': 25,
#   '行政區': '士林區'}
# { '可借': 13,
#   '可還': 26,
#   '地址': '至誠路二段47-49號(前)',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_芝山抽水站',
#   '總車輛數': 46,
#   '行政區': '士林區'}
# { '可借': 7,
#   '可還': 14,
#   '地址': '至誠路一段303號(對面)',
#   '日期': '2024-09-04 19:32:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_至誠路一段305巷口',
#   '總車輛數': 21,
#   '行政區': '士林區'}
# { '可借': 14,
#   '可還': 18,
#   '地址': '劍潭路76號(對面)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_華齡公園',
#   '總車輛數': 32,
#   '行政區': '士林區'}
# { '可借': 13,
#   '可還': 5,
#   '地址': '後港街134巷/後港街口',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_前港公園(福德宮)',
#   '總車輛數': 18,
#   '行政區': '士林區'}
# { '可借': 7,
#   '可還': 0,
#   '地址': '華齡街188號(前)',
#   '日期': '2024-09-04 19:36:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_華齡街185巷口',
#   '總車輛數': 12,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 22,
#   '地址': '前港街48號(對面)',
#   '日期': '2024-09-04 19:39:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_前港公園(前港街)',
#   '總車輛數': 27,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 20,
#   '地址': '承德路四段179巷/承德路4段口',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_百齡高中',
#   '總車輛數': 27,
#   '行政區': '士林區'}
# { '可借': 0,
#   '可還': 21,
#   '地址': '福華路151號(對面)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運芝山站(2號出口)',
#   '總車輛數': 21,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 21,
#   '地址': '文林路751號(南側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺灣戲曲中心',
#   '總車輛數': 25,
#   '行政區': '士林區'}
# { '可借': 10,
#   '可還': 39,
#   '地址': '基河路18號(對面)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運劍潭站(2號出口)',
#   '總車輛數': 49,
#   '行政區': '士林區'}
# { '可借': 1,
#   '可還': 52,
#   '地址': '劍潭路基河路口(捷運站橋下空間)',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_劍潭基河路口',
#   '總車輛數': 66,
#   '行政區': '士林區'}
# { '可借': 8,
#   '可還': 15,
#   '地址': '中正路/雨農路口(西北側)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_志成公園',
#   '總車輛數': 23,
#   '行政區': '士林區'}
# { '可借': 2,
#   '可還': 12,
#   '地址': '福志路50號(對面)',
#   '日期': '2024-09-04 19:37:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_福林國小',
#   '總車輛數': 14,
#   '行政區': '士林區'}
# { '可借': 9,
#   '可還': 9,
#   '地址': '中山北路五段609號(前)',
#   '日期': '2024-09-04 19:43:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_中山中正路口',
#   '總車輛數': 19,
#   '行政區': '士林區'}
# { '可借': 16,
#   '可還': 14,
#   '地址': '士商路1號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_士林運動中心',
#   '總車輛數': 30,
#   '行政區': '士林區'}
# { '可借': 0,
#   '可還': 34,
#   '地址': '中正路510號(前)',
#   '日期': '2024-09-04 19:33:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_陽明高中',
#   '總車輛數': 36,
#   '行政區': '士林區'}
# { '可借': 19,
#   '可還': 1,
#   '地址': '承德路五段55號(旁公車亭)',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_兒童新樂園',
#   '總車輛數': 23,
#   '行政區': '士林區'}
# { '可借': 18,
#   '可還': 28,
#   '地址': '基河路363號(前)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北市立天文館',
#   '總車輛數': 46,
#   '行政區': '士林區'}
# { '可借': 8,
#   '可還': 26,
#   '地址': '華聲街17號(南側路側)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_華聲公園',
#   '總車輛數': 35,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 21,
#   '地址': '福林路/中山北路五段(東北側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_福林公園',
#   '總車輛數': 25,
#   '行政區': '士林區'}
# { '可借': 2,
#   '可還': 28,
#   '地址': '中山北路五段505巷44弄2號(對面)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運士林站(2號出口)',
#   '總車輛數': 30,
#   '行政區': '士林區'}
# { '可借': 6,
#   '可還': 20,
#   '地址': '中山北路五段250號(銘傳大學對側)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_銘傳大學',
#   '總車輛數': 26,
#   '行政區': '士林區'}
# { '可借': 8,
#   '可還': 18,
#   '地址': '士商路150號(校門旁)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_士林高商',
#   '總車輛數': 26,
#   '行政區': '士林區'}
# { '可借': 9,
#   '可還': 29,
#   '地址': '忠誠路二段/忠誠路二段40巷(西南側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_蘭雅公園',
#   '總車輛數': 38,
#   '行政區': '士林區'}
# { '可借': 1,
#   '可還': 24,
#   '地址': '雨聲街105號(南側)',
#   '日期': '2024-09-04 19:28:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_聯合醫院陽明院區',
#   '總車輛數': 25,
#   '行政區': '士林區'}
# { '可借': 0,
#   '可還': 36,
#   '地址': '福華路114號(對面)',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運芝山站(1號出口)',
#   '總車輛數': 36,
#   '行政區': '士林區'}
# { '可借': 2,
#   '可還': 18,
#   '地址': '至誠路一段80號(對面)',
#   '日期': '2024-09-04 19:32:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_至誠公園',
#   '總車輛數': 20,
#   '行政區': '士林區'}
# { '可借': 3,
#   '可還': 18,
#   '地址': '至善路二段280號(對面)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_原住民文化主題公園',
#   '總車輛數': 21,
#   '行政區': '士林區'}
# { '可借': 7,
#   '可還': 8,
#   '地址': '通河東街2段5號(對面)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_通河東街2段10巷口',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 21,
#   '地址': '至善路一段/至善路一段138巷(北側)',
#   '日期': '2024-09-04 19:35:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_梅林新村',
#   '總車輛數': 25,
#   '行政區': '士林區'}
# { '可借': 17,
#   '可還': 13,
#   '地址': '中正路613號(對面)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_延平北中正路口',
#   '總車輛數': 30,
#   '行政區': '士林區'}
# { '可借': 4,
#   '可還': 9,
#   '地址': '重慶北路四段198號(前)',
#   '日期': '2024-09-04 19:38:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶北路四段190巷口',
#   '總車輛數': 13,
#   '行政區': '士林區'}
# { '可借': 8,
#   '可還': 7,
#   '地址': '重慶北路四段177號(前)',
#   '日期': '2024-09-04 19:36:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶北葫東街口',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 20,
#   '可還': 10,
#   '地址': '環河北路三段/葫蘆街(東北側)',
#   '日期': '2024-09-04 19:41:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_葫蘆國小',
#   '總車輛數': 30,
#   '行政區': '士林區'}
# { '可借': 1,
#   '可還': 37,
#   '地址': '中山北路六段81號(旁)',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_士林3號廣場',
#   '總車輛數': 38,
#   '行政區': '士林區'}
# { '可借': 9,
#   '可還': 6,
#   '地址': '社中街39號(對面)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_社正公園',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 0,
#   '可還': 15,
#   '地址': '社中街476號(對面)',
#   '日期': '2024-08-13 00:56:14',
#   '狀態': '0',
#   '站名': 'YouBike2.0_社子國小',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 22,
#   '可還': 2,
#   '地址': '通河西街二段194號(對面)',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_社中街384巷口',
#   '總車輛數': 24,
#   '行政區': '士林區'}
# { '可借': 14,
#   '可還': 1,
#   '地址': '忠誠路一段138號(斜前方)',
#   '日期': '2024-09-04 19:42:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_忠誠路一段138號',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 11,
#   '可還': 11,
#   '地址': '永平街20巷37弄/永平街20巷11弄(社子公園南側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_社子公園',
#   '總車輛數': 32,
#   '行政區': '士林區'}
# { '可借': 2,
#   '可還': 15,
#   '地址': '力行街8號(對面)',
#   '日期': '2024-09-04 19:04:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_國立故宮博物院',
#   '總車輛數': 17,
#   '行政區': '士林區'}
# { '可借': 1,
#   '可還': 22,
#   '地址': '福林路240號(前)',
#   '日期': '2024-09-04 19:35:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_泰北高中',
#   '總車輛數': 23,
#   '行政區': '士林區'}
# { '可借': 7,
#   '可還': 8,
#   '地址': '通河東街二段26號(旁公園)',
#   '日期': '2024-09-04 18:53:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_後港公園',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 17,
#   '可還': 7,
#   '地址': '重慶北路四段117號(前)',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_重慶北路四段117號',
#   '總車輛數': 24,
#   '行政區': '士林區'}
# { '可借': 5,
#   '可還': 17,
#   '地址': '延平北路九段323號(後方堤外)',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_社子島島頭公園',
#   '總車輛數': 22,
#   '行政區': '士林區'}
# { '可借': 3,
#   '可還': 19,
#   '地址': '延平北路八段133巷42號(對面)',
#   '日期': '2024-09-04 19:27:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_延平北路八段133巷口',
#   '總車輛數': 22,
#   '行政區': '士林區'}
# { '可借': 1,
#   '可還': 13,
#   '地址': '延平北路八段96巷15號(前)',
#   '日期': '2024-09-04 19:29:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_坤天亭',
#   '總車輛數': 14,
#   '行政區': '士林區'}
# { '可借': 2,
#   '可還': 13,
#   '地址': '社子島濕地解說小築',
#   '日期': '2024-09-04 19:07:22',
#   '狀態': '1',
#   '站名': 'YouBike2.0_社子島濕地解說小築',
#   '總車輛數': 15,
#   '行政區': '士林區'}
# { '可借': 17,
#   '可還': 8,
#   '地址': '延平北路七段250號(前)',
#   '日期': '2024-09-04 18:17:21',
#   '狀態': '1',
#   '站名': 'YouBike2.0_福安國中',
#   '總車輛數': 25,
#   '行政區': '士林區'}
# { '可借': 6,
#   '可還': 13,
# ...
# { '可借': 7,
#   '可還': 8,
#   '地址': '成都路108號(對面)',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_貓公園(中興橋頭)',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 24,
#   '可還': 63,
#   '地址': '中華路一段164號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_西本願寺廣場',
#   '總車輛數': 87,
#   '行政區': '萬華區'}
# { '可借': 6,
#   '可還': 28,
#   '地址': '中華路一段與桂林路口西北側',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_中華桂林路口',
#   '總車輛數': 34,
#   '行政區': '萬華區'}
# { '可借': 0,
#   '可還': 30,
#   '地址': '和平西路三段/西園路一段(東北側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運龍山寺站(1號出口)',
#   '總車輛數': 30,
#   '行政區': '萬華區'}
# { '可借': 6,
#   '可還': 24,
#   '地址': '和平西路三段235號(旁)',
#   '日期': '2024-09-04 19:35:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_龍山國小',
#   '總車輛數': 30,
#   '行政區': '萬華區'}
# { '可借': 43,
#   '可還': 7,
#   '地址': '桂林路134號(對面)',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_華西公園',
#   '總車輛數': 51,
#   '行政區': '萬華區'}
# { '可借': 37,
#   '可還': 13,
#   '地址': '康定路238號(對面)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_老松國小',
#   '總車輛數': 50,
#   '行政區': '萬華區'}
# { '可借': 13,
#   '可還': 40,
#   '地址': '艋舺大道83號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬華火車站',
#   '總車輛數': 53,
#   '行政區': '萬華區'}
# { '可借': 0,
#   '可還': 42,
#   '地址': '康定路/康定路287巷(東南側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬華火車站(D2廣場)',
#   '總車輛數': 42,
#   '行政區': '萬華區'}
# { '可借': 2,
#   '可還': 21,
#   '地址': '和平西路三段/和平西路三段88巷(西南側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運龍山寺站(3號出口)',
#   '總車輛數': 23,
#   '行政區': '萬華區'}
# { '可借': 3,
#   '可還': 12,
#   '地址': '峨嵋街100號(對面)',
#   '日期': '2024-09-04 19:39:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北市電影主題公園(峨眉街)',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 6,
#   '可還': 9,
#   '地址': '康定路18-2號(對面)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺北市電影主題公園(康定路)',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 7,
#   '可還': 17,
#   '地址': '中華路一段130號(前)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_中華峨眉街口',
#   '總車輛數': 24,
#   '行政區': '萬華區'}
# { '可借': 5,
#   '可還': 10,
#   '地址': '康定路81號(對面)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬華266號綠地',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 0,
#   '可還': 18,
#   '地址': '萬大路346號(旁)',
#   '日期': '2024-09-04 19:26:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬大國小(萬大路344巷口)',
#   '總車輛數': 18,
#   '行政區': '萬華區'}
# { '可借': 10,
#   '可還': 7,
#   '地址': '德昌街15號(對面)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_德昌街10巷口',
#   '總車輛數': 17,
#   '行政區': '萬華區'}
# { '可借': 12,
#   '可還': 8,
#   '地址': '環河南路一段/和平西路三段口(西南側)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_環河南和平西路口',
#   '總車輛數': 20,
#   '行政區': '萬華區'}
# { '可借': 4,
#   '可還': 11,
#   '地址': '長順街60巷38號對側',
#   '日期': '2024-09-04 19:14:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_長順街60巷口',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 1,
#   '可還': 13,
#   '地址': '東園街35巷/東園街67巷交叉口',
#   '日期': '2024-09-04 19:40:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_西園公園',
#   '總車輛數': 14,
#   '行政區': '萬華區'}
# { '可借': 9,
#   '可還': 11,
#   '地址': '桂林路246巷66號南側',
#   '日期': '2024-09-04 19:31:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_華江污水廠',
#   '總車輛數': 20,
#   '行政區': '萬華區'}
# { '可借': 9,
#   '可還': 19,
#   '地址': '環河南路二段100巷15號對側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_柳鄉公園',
#   '總車輛數': 30,
#   '行政區': '萬華區'}
# { '可借': 16,
#   '可還': 12,
#   '地址': '大理街170巷與環河南路二段159巷口',
#   '日期': '2024-09-04 19:45:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_綠堤社區公園',
#   '總車輛數': 28,
#   '行政區': '萬華區'}
# { '可借': 1,
#   '可還': 25,
#   '地址': '長順街與雙園街106巷口',
#   '日期': '2024-09-04 19:23:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_長順艋舺大道口',
#   '總車輛數': 26,
#   '行政區': '萬華區'}
# { '可借': 3,
#   '可還': 16,
#   '地址': '富民路151號對側',
#   '日期': '2024-09-04 19:00:23',
#   '狀態': '1',
#   '站名': 'YouBike2.0_富民路145巷口',
#   '總車輛數': 20,
#   '行政區': '萬華區'}
# { '可借': 3,
#   '可還': 11,
#   '地址': '環河南路二段245號旁',
#   '日期': '2024-09-04 19:18:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_環南綜合市場',
#   '總車輛數': 14,
#   '行政區': '萬華區'}
# { '可借': 12,
#   '可還': 3,
#   '地址': '南寧路與廣州街口南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_龍山國中',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 12,
#   '可還': 8,
#   '地址': '昆明街與洛陽街口西側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_洛陽停車場',
#   '總車輛數': 22,
#   '行政區': '萬華區'}
# { '可借': 9,
#   '可還': 20,
#   '地址': '桂林路與昆明街口西北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_桂林昆明街口',
#   '總車輛數': 29,
#   '行政區': '萬華區'}
# { '可借': 17,
#   '可還': 19,
#   '地址': '西藏路 / 莒光路299巷口(東南側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬華國中_1',
#   '總車輛數': 36,
#   '行政區': '萬華區'}
# { '可借': 27,
#   '可還': 19,
#   '地址': '青年路/青年路106巷(東側)',
#   '日期': '2024-09-04 19:42:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_青年公園3號出口',
#   '總車輛數': 46,
#   '行政區': '萬華區'}
# { '可借': 0,
#   '可還': 48,
#   '地址': '和平西路三段/和平西路三段109巷(西北側)',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_捷運龍山寺站(1號出口)_1',
#   '總車輛數': 49,
#   '行政區': '萬華區'}
# { '可借': 17,
#   '可還': 13,
#   '地址': '萬大路與興寧街66巷22弄口西北側',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_莒光社會住宅',
#   '總車輛數': 30,
#   '行政區': '萬華區'}
# { '可借': 6,
#   '可還': 14,
#   '地址': '艋舺大道與西藏路口西南側(華翠大橋下)',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_艋舺西藏路口',
#   '總車輛數': 20,
#   '行政區': '萬華區'}
# { '可借': 5,
#   '可還': 5,
#   '地址': '萬大路493巷44號旁',
#   '日期': '2024-09-04 19:44:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬大路493巷',
#   '總車輛數': 10,
#   '行政區': '萬華區'}
# { '可借': 5,
#   '可還': 7,
#   '地址': '西園路二段320巷55弄8-10號前',
#   '日期': '2024-09-04 19:20:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_雙園國中地下停車場',
#   '總車輛數': 12,
#   '行政區': '萬華區'}
# { '可借': 6,
#   '可還': 11,
#   '地址': '青年路152巷59號對側',
#   '日期': '2024-09-04 19:32:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_青年路152巷口',
#   '總車輛數': 23,
#   '行政區': '萬華區'}
# { '可借': 2,
#   '可還': 13,
#   '地址': '和平西路二段190巷11號前',
#   '日期': '2024-09-04 19:18:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_和平西路二段190巷口',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 4,
#   '可還': 11,
#   '地址': '環河南路三段/萬大路424巷',
#   '日期': '2024-09-04 19:36:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬大路424巷口',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 4,
#   '可還': 8,
#   '地址': '長泰街45號對側',
#   '日期': '2024-09-04 19:36:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_長泰街52巷口',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 9,
#   '可還': 15,
#   '地址': '水源路與青年路口北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_水源青年路口',
#   '總車輛數': 24,
#   '行政區': '萬華區'}
# { '可借': 8,
#   '可還': 16,
#   '地址': '青年路162號對側人行道',
#   '日期': '2024-09-04 19:35:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_青年公園4號出口',
#   '總車輛數': 24,
#   '行政區': '萬華區'}
# { '可借': 7,
#   '可還': 5,
#   '地址': '水源路207之7號前',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_祥安水岸景觀大廈',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 2,
#   '可還': 17,
#   '地址': '環河南路二段與西藏路口',
#   '日期': '2024-09-04 19:27:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_大理高中(西藏路)',
#   '總車輛數': 19,
#   '行政區': '萬華區'}
# { '可借': 5,
#   '可還': 9,
#   '地址': '環河南路二段159巷口',
#   '日期': '2024-09-04 19:26:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_綠堤公園(西北側)',
#   '總車輛數': 14,
#   '行政區': '萬華區'}
# { '可借': 7,
#   '可還': 7,
#   '地址': '艋舺大道404號前方',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_艋舺雙園街口',
#   '總車輛數': 14,
#   '行政區': '萬華區'}
# { '可借': 8,
#   '可還': 5,
#   '地址': '德昌街142號對側',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_德昌街125巷口',
#   '總車輛數': 15,
#   '行政區': '萬華區'}
# { '可借': 19,
#   '可還': 2,
#   '地址': '萬青街186號',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_萬青街186號',
#   '總車輛數': 21,
#   '行政區': '萬華區'}
# { '可借': 35,
#   '可還': 2,
#   '地址': '汀洲路三段60巷2弄路側(A舍北側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大水源舍區A棟',
#   '總車輛數': 37,
#   '行政區': '臺大公館校區'}
# { '可借': 5,
#   '可還': 87,
#   '地址': '臺大水源舍區C南側',
#   '日期': '2024-09-04 19:40:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大卓越研究大樓',
#   '總車輛數': 92,
#   '行政區': '臺大公館校區'}
# { '可借': 8,
#   '可還': 27,
#   '地址': '思源街16號之1旁',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大水源修齊會館',
#   '總車輛數': 35,
#   '行政區': '臺大公館校區'}
# { '可借': 4,
#   '可還': 6,
#   '地址': '臺大檔案展示館東北側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大檔案展示館',
#   '總車輛數': 10,
#   '行政區': '臺大公館校區'}
# { '可借': 24,
#   '可還': 6,
#   '地址': '汀洲路三段60巷2弄路側(B舍北側)',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大水源舍區B棟',
#   '總車輛數': 30,
#   '行政區': '臺大公館校區'}
# { '可借': 6,
#   '可還': 36,
#   '地址': '臺大男八舍東側',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大男八舍東側',
#   '總車輛數': 42,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 34,
#   '地址': '臺大仰萃樓東南側',
#   '日期': '2024-09-04 19:34:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大禮賢樓東南側',
#   '總車輛數': 35,
#   '行政區': '臺大公館校區'}
# { '可借': 14,
#   '可還': 31,
#   '地址': '農業陳列館北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大農業陳列館北側',
#   '總車輛數': 45,
#   '行政區': '臺大公館校區'}
# { '可借': 4,
#   '可還': 36,
#   '地址': '管理學院二號館北側',
#   '日期': '2024-09-04 19:43:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大管理學院二館北側',
#   '總車輛數': 40,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 30,
#   '地址': '臺大土木工程學系所南側',
#   '日期': '2024-09-04 19:23:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大土木系館',
#   '總車輛數': 30,
#   '行政區': '臺大公館校區'}
# { '可借': 26,
#   '可還': 26,
#   '地址': '臺大女一舍北側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大大一女舍北側',
#   '總車輛數': 53,
#   '行政區': '臺大公館校區'}
# { '可借': 2,
#   '可還': 96,
#   '地址': '臺大女九舍西南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大女九舍西南側',
#   '總車輛數': 99,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 30,
#   '地址': '臺大小福樓東側',
#   '日期': '2024-09-04 19:42:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大小福樓東側',
#   '總車輛數': 31,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 26,
#   '地址': '基隆路三段/基隆路三段156巷口北側',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大立體機車停車場',
#   '總車輛數': 27,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 26,
#   '地址': '臺大工學院東南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大工綜館南側',
#   '總車輛數': 26,
#   '行政區': '臺大公館校區'}
# { '可借': 5,
#   '可還': 14,
#   '地址': '臺大天文數學館西南側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大天文數學館南側',
#   '總車輛數': 19,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 29,
#   '地址': '臺大心理學系南側',
#   '日期': '2024-09-04 19:30:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大心理系館南側',
#   '總車輛數': 30,
#   '行政區': '臺大公館校區'}
# { '可借': 3,
#   '可還': 25,
#   '地址': '臺大文學院西側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大樂學館東側',
#   '總車輛數': 28,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 10,
#   '地址': '臺大生化科技學系西側',
#   '日期': '2024-09-04 19:42:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大農化新館西側',
#   '總車輛數': 10,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 48,
#   '地址': '臺大生物系館西側',
#   '日期': '2024-09-04 19:27:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大五號館西側',
#   '總車輛數': 48,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 32,
#   '地址': '臺大田徑場東側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大舊體育館西側',
#   '總車輛數': 33,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 68,
#   '地址': '臺大共同教學館東北側',
#   '日期': '2024-09-04 19:29:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大共同教室北側',
#   '總車輛數': 68,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 12,
#   '地址': '臺大共同教學館東南側',
#   '日期': '2024-09-04 19:30:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大共同教室東南側',
#   '總車輛數': 12,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 38,
#   '地址': '臺大鹿鳴廣場人行道側',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大鹿鳴堂東側',
#   '總車輛數': 39,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 12,
#   '地址': '臺大公館停車場西北側',
#   '日期': '2024-09-04 19:41:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大公館停車場西北側',
#   '總車輛數': 12,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 26,
#   '地址': '臺大行政大樓西側',
#   '日期': '2024-09-04 19:17:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大第二行政大樓南側',
#   '總車輛數': 27,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 27,
#   '地址': '臺大明達館西側',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大明達館機車停車場',
#   '總車輛數': 28,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 10,
#   '地址': '臺大物理文物廳北側',
#   '日期': '2024-09-04 19:28:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大二號館',
#   '總車輛數': 10,
#   '行政區': '臺大公館校區'}
# { '可借': 2,
#   '可還': 18,
#   '地址': '臺大物理系館南側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大凝態館南側',
#   '總車輛數': 20,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 42,
#   '地址': '臺大社科院西側',
#   '日期': '2024-09-04 19:40:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大社科院西側',
#   '總車輛數': 42,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 66,
#   '地址': '臺大社會及社工館南側',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大社會系館南側',
#   '總車輛數': 66,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 26,
#   '地址': '臺大思亮館東南側',
#   '日期': '2024-09-04 19:43:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大思亮館東南側',
#   '總車輛數': 26,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 47,
#   '地址': '臺大椰林小舖旁',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大椰林小舖',
#   '總車輛數': 48,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 34,
#   '地址': '臺大計算機網路資訊中心南側',
#   '日期': '2024-09-04 19:44:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大計資中心南側',
#   '總車輛數': 34,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 12,
#   '地址': '臺大原子與分子科學研究所東北側',
#   '日期': '2024-09-04 19:21:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大原分所北側',
#   '總車輛數': 12,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 30,
#   '地址': '臺大動物博物館西側',
#   '日期': '2024-09-04 18:48:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大生命科學館西北側',
#   '總車輛數': 30,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 47,
#   '地址': '第一學生活動中心東南側',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大第一活動中心西南側',
#   '總車輛數': 48,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 22,
#   '地址': '臺大博理館西側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大博理館西側',
#   '總車輛數': 22,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 55,
#   '地址': '臺大博雅館西側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大博雅館西側',
#   '總車輛數': 56,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 9,
#   '地址': '臺大森林系學系北側',
#   '日期': '2024-09-04 19:28:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大森林館北側',
#   '總車輛數': 10,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 18,
#   '地址': '臺大植物魚類標本館一號館北側',
#   '日期': '2024-09-04 19:40:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大一號館',
#   '總車輛數': 19,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 10,
#   '地址': '臺大進修教育大樓',
#   '日期': '2024-09-04 18:38:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大小小福西南側',
#   '總車輛數': 10,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 26,
#   '地址': '臺大雅頌廣場東南側',
#   '日期': '2024-09-04 19:39:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大教研館北側',
#   '總車輛數': 26,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 10,
#   '地址': '臺大園藝暨景觀學系北側',
#   '日期': '2024-09-04 19:28:14',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大四號館東北側',
#   '總車輛數': 10,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 18,
#   '地址': '臺大新生教學館南側',
#   '日期': '2024-09-04 19:33:16',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大新生教室南側',
#   '總車輛數': 18,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 40,
#   '地址': '臺大鄭江樓東南側',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大鄭江樓北側',
#   '總車輛數': 40,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 13,
#   '地址': '臺大電機二館南側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大電機二館東南側',
#   '總車輛數': 14,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 51,
#   '地址': '臺大圖書資訊館北側',
#   '日期': '2024-09-04 19:40:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大圖資系館北側',
#   '總車輛數': 51,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 30,
#   '地址': '臺大圖書館西南側',
#   '日期': '2024-09-04 19:40:17',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大總圖書館西南側',
#   '總車輛數': 30,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 34,
#   '地址': '臺大霖澤館南側',
#   '日期': '2024-09-04 19:44:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大黑森林西側',
#   '總車輛數': 35,
#   '行政區': '臺大公館校區'}
# { '可借': 2,
#   '可還': 21,
#   '地址': '臺大獸醫系館南側',
#   '日期': '2024-09-04 19:45:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大獸醫館南側',
#   '總車輛數': 24,
#   '行政區': '臺大公館校區'}
# { '可借': 1,
#   '可還': 38,
#   '地址': '臺大體育館東側',
#   '日期': '2024-09-04 19:45:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大新體育館東南側',
#   '總車輛數': 40,
#   '行政區': '臺大公館校區'}
# { '可借': 5,
#   '可還': 13,
#   '地址': '明達館北側前空地',
#   '日期': '2024-09-04 19:40:20',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大明達館北側(員工宿舍)',
#   '總車輛數': 18,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 17,
#   '地址': '臺大管理學院一館前',
#   '日期': '2024-09-04 19:16:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大管理學院一館',
#   '總車輛數': 17,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 36,
#   '地址': '臺大禮賢樓西側空地',
#   '日期': '2024-09-04 18:26:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大禮賢樓西側',
#   '總車輛數': 36,
#   '行政區': '臺大公館校區'}
# { '可借': 21,
#   '可還': 19,
#   '地址': '臺大大一女餐廳廣場後方',
#   '日期': '2024-09-04 19:36:18',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大大一女餐廳廣場',
#   '總車輛數': 40,
#   '行政區': '臺大公館校區'}
# { '可借': 0,
#   '可還': 32,
#   '地址': '臺大學新館旁',
#   '日期': '2024-09-04 19:44:15',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大學新館',
#   '總車輛數': 33,
#   '行政區': '臺大公館校區'}
# { '可借': 7,
#   '可還': 92,
#   '地址': '臺大水源舍區C棟西側',
#   '日期': '2024-09-04 18:26:19',
#   '狀態': '1',
#   '站名': 'YouBike2.0_臺大水源舍區C棟',
#   '總車輛數': 99,
#   '行政區': '臺大公館校區'}
