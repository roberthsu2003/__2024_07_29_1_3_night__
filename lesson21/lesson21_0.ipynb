# %%
import requests
from requests import ConnectionError,HTTPError,Timeout
url = 'https://data.ntpc.gov.tw/api/datasets/010E5B15-3823-4B20-B401-B1CF000550C5/json?page=0&size=2000'
try:
    response = requests.get(url)    
    response.raise_for_status()    
except ConnectionError:
    print('找不到伺服器')
except HTTPError:
    print('網頁找不到')
except Timeout:
    print('超過時間沒有回應')
else:
    print('沒有發生問題')

import pandas as pd
df1 = pd.DataFrame(response.json(),
                   columns=['sna','tot','sbi','sarea','ar','bemp'])

df2 = df1.rename(columns={'sna':'站名', 'sarea':'區域', 'ar':'地址', 'tot':'數量','sbi':'可借', 'bemp':'可還'})

#小心資料類型
df2.info()
df2
# Out:
# 沒有發生問題
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      1000 non-null   object
#  1   數量      1000 non-null   object
#  2   可借      1000 non-null   object
#  3   區域      1000 non-null   object
#  4   地址      1000 non-null   object
#  5   可還      1000 non-null   object
# dtypes: object(6)
# memory usage: 47.0+ KB
#                         站名  數量  可借   區域                      地址  可還
# 0          YouBike2.0_下庄市場  20   4  八里區               舊城路21號(前)  16
# 1        YouBike2.0_八里行政中心  20   8  八里區    十三行路(靠中山路二段路口西南側人行道)  12
# 2    YouBike2.0_八里中庄市場綜合大樓  28  10  八里區    中山路一段268巷2號(對面汽車停車場)  18
# 3          YouBike2.0_大崁國小  20   5  八里區                忠八街2號(前)  15
# 4         YouBike2.0_龍形停車場  40  11  八里區        龍米路一段318號(對面停車場)  29
# ..                     ...  ..  ..  ...                     ...  ..
# 995        YouBike2.0_青潭國小  27   9  新店區                北宜路二段80號  18
# 996     YouBike2.0_中正路284巷  29  27  新店區           中正路284巷4弄3號南側   2
# 997      YouBike2.0_央北社會住宅  58   6  新店區        央北二路十四張口(西南側人行道)  52
# 998  YouBike2.0_中興路2段100巷口  21   6  新店區  五峰路63巷/中興路二段100巷口(天橋旁)  15
# 999      YouBike2.0_台北慈濟醫院  40   4  新店區              建國路289號旁空地  36
#
# [1000 rows x 6 columns]

# %%
df2[['數量', '可還', '可借']]= df2[['數量', '可還', '可借']].astype(int)

# %%
df3 = df2[['區域', '數量', '可還', '可借']]
df3
# Out:
#       區域  數量  可還  可借
# 0    八里區  20  16   4
# 1    八里區  20  12   8
# 2    八里區  28  18  10
# 3    八里區  20  15   5
# 4    八里區  40  29  11
# ..   ...  ..  ..  ..
# 995  新店區  27  18   9
# 996  新店區  29   2  27
# 997  新店區  58  52   6
# 998  新店區  21  15   6
# 999  新店區  40  36   4
#
# [1000 rows x 4 columns]

# %%
groupby = df3.groupby(by='區域')
groupby.sum()
# Out:
#        數量    可還    可借
# 區域
# 三峽區  1482   940   540
# 三芝區   153    61    44
# 三重區  3592  2314  1259
# 中和區  3381  2191  1168
# 五股區   566   359   204
# 八里區   443   305   138
# 土城區  2737  1749   948
# 坪林區    65     0     0
# 新店區  2031  1205   804
# 板橋區  6983  4727  2185
# 林口區  2073  1211   847
# 永和區  1545  1010   530
# 汐止區  2353  1318  1010
# 泰山區   526   364   157
# 淡水區  1909  1207   698
# 深坑區   122    68    54
# 瑞芳區   204    76    38
# 石碇區    29     0     0
# 石門區    82     0     0
# 萬里區    99    22     6
# 金山區   163    80    55
